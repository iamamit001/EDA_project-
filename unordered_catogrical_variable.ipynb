# %%
# it is possoble to extract meaningful insight fromm unordered catogrical variables using rank- frequency plots.

# %%
import pandas as pd
import numpy as np

# %%
emp = pd.read_excel("unordered+employment.xlsx")
emp.head(10)
# Out:
#    Rank Current Location  COUNTA of Current Location  Unnamed: 3  Unnamed: 4  \
# 0   1.0          Chennai                       29648         NaN         NaN
# 1   2.0       Coimbatore                        3596         NaN         NaN
# 2   3.0           Trichy                        2092         NaN         NaN
# 3   4.0          Madurai                        1460         NaN         NaN
# 4   5.0            Salem                        1361         NaN         NaN
# 5   6.0          Vellore                        1010         NaN         NaN
# 6   7.0            Erode                         791         NaN         NaN
# 7   8.0      Tirunalveli                         731         NaN         NaN
# 8   9.0            Hosur                         714         NaN         NaN
# 9  10.0        Cuddalore                         619         NaN         NaN
#
#    log rank  log count
# 0       NaN        NaN
# 1       NaN        NaN
# 2       NaN        NaN
# 3       NaN        NaN
# ...

# %%
emp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 318 entries, 0 to 317
# Data columns (total 7 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Rank                        317 non-null    float64
#  1   Current Location            317 non-null    object
#  2   COUNTA of Current Location  318 non-null    int64
#  3   Unnamed: 3                  0 non-null      float64
#  4   Unnamed: 4                  0 non-null      float64
#  5   log rank                    0 non-null      float64
#  6   log count                   0 non-null      float64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 17.5+ KB

# %%
emp.isnull().sum()
# Out:
# Rank                            1
# Current Location                1
# COUNTA of Current Location      0
# Unnamed: 3                    318
# Unnamed: 4                    318
# log rank                      318
# log count                     318
# dtype: int64

# %%
emp['COUNTA of Current Location'].plot.hist()
# Out:
# <Axes: ylabel='Frequency'>

# %%
emp['COUNTA of Current Location'].value_counts().plot()
# Out:
# <Axes: xlabel='COUNTA of Current Location'>

# %%
emp['Rank'].plot()
# Out:
# <Axes: >

# %%
emp['Rank'].value_counts().plot.bar()
# Out:
# <Axes: xlabel='Rank'>

# %%
emp['Rank'].value_counts(normalize = True).plot.bar()
# Out:
# <Axes: xlabel='Rank'>

# %%
1/317
# Out:
# 0.0031545741324921135

# %%
data = pd.read_csv('https://raw.githubusercontent.com/pycaret/pycaret/master/datasets/diamond.csv')
data.head()
# Out:
#    Carat Weight    Cut Color Clarity Polish Symmetry Report  Price
# 0          1.10  Ideal     H     SI1     VG       EX    GIA   5169
# 1          0.83  Ideal     H     VS1     ID       ID   AGSL   3470
# 2          0.85  Ideal     H     SI1     EX       EX    GIA   3183
# 3          0.91  Ideal     E     SI1     VG       VG    GIA   4370
# 4          0.83  Ideal     G     SI1     EX       EX    GIA   3171

# %%
data.Cut.value_counts()
# Out:
# Cut
# Ideal              2482
# Very Good          2428
# Good                708
# Signature-Ideal     253
# Fair                129
# Name: count, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6000 entries, 0 to 5999
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Carat Weight  6000 non-null   float64
#  1   Cut           6000 non-null   object
#  2   Color         6000 non-null   object
#  3   Clarity       6000 non-null   object
#  4   Polish        6000 non-null   object
#  5   Symmetry      6000 non-null   object
#  6   Report        6000 non-null   object
#  7   Price         6000 non-null   int64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 375.1+ KB

# %%
import matplotlib.pyplot as plt

# %%
import plotly.express as px
cut_data = data.Cut.value_counts()
fig=px.bar(x = cut_data.index , y = cut_data.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
colur_data = data.Color.value_counts()
fig = px.bar(x =colur_data.index, y = colur_data.values)

# %%
colur_data = data.Color.value_counts()
fig = px.bar(x =colur_data.index, y = colur_data.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
import seaborn as sns

# %%
report_data = data.Report.value_counts()
fig = px.bar(x = report_data.index, y = report_data.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
polish_data = data.Polish.value_counts()
fig = px.bar(x = polish_data.index, y = polish_data.values)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
data.groupby(by='Cut')['Carat Weight'].mean()
# Out:
# Cut
# Fair               1.058682
# Good               1.268927
# Ideal              1.382293
# Signature-Ideal    1.205217
# Very Good          1.332941
# Name: Carat Weight, dtype: float64

# %%
#one hot encoding = tranfrom catogrical value into numerical values

datadict = {
    "fruits" :['apple','banana','kivi','orange','orange']
}
df =pd.DataFrame(datadict)
df.head(10)
# Out:
#    fruits
# 0   apple
# 1  banana
# 2    kivi
# 3  orange
# 4  orange

# %%
data_enoce = pd.get_dummies(df['fruits'])
data_enoce
# Out:
#    apple  banana   kivi  orange
# 0   True   False  False   False
# 1  False    True  False   False
# 2  False   False   True   False
# 3  False   False  False    True
# 4  False   False  False    True
